# %% [markdown]
# # IT Academy - Data Science amb Python
# ## Tasca 7: Estructura de control
#
# ###  [Github Registre de Logs](https://github.com/jesussantana/Registre_de_logs)

# %% [markdown]
# ###  Exercici 1
# - Normalitza, identifica i enumera cada un dels atributs / variables de l'estructura de l'arxiu "Web_access_log-akumenius.com" que trobaràs al repositori de GitHub "Data-sources".

# %%
import numpy as np
import pandas as pd
from io import StringIO
import requests
import re

path = '../Data/Web_access_log-akumenius.com.txt'

Logs = pd.read_csv(path, sep='\s | - | \"', names =['DNS','IP','Location','Date','Time','Request','Status','Size','Referer','UserAgent'], skiprows=250771, engine='python')

Logs
# Out:
#                                    DNS                              IP  \
# 0         www.akumenius.com 5.10.83.86  - [01/Mar/2014:13:29:00 +0100]
# 1         www.akumenius.com 5.10.83.44  - [01/Mar/2014:13:29:00 +0100]
# 2       www.akumenius.com 66.249.64.98  - [01/Mar/2014:13:29:02 +0100]
# 3       www.akumenius.com 89.130.90.61  - [01/Mar/2014:13:29:06 +0100]
# 4       www.akumenius.com 89.130.90.61  - [01/Mar/2014:13:29:11 +0100]
# ...                                ...                             ...
# 11097   www.akumenius.com 5.255.253.53  - [02/Mar/2014:03:05:39 +0100]
# 11098  www.akumenius.com 74.86.158.107  - [02/Mar/2014:03:09:52 +0100]
# 11099              localhost 127.0.0.1  - [02/Mar/2014:03:10:18 +0100]
# 11100              localhost 127.0.0.1  - [02/Mar/2014:03:10:18 +0100]
# 11101              localhost 127.0.0.1  - [02/Mar/2014:03:10:18 +0100]
#
#                                                 Location  \
# 0      GET /destinosEstrelles/hoteles-en-Mykonos_GREC...
# 1      GET /destinos-baratos/hoteles-baratos/ofertas-...
# 2      GET /destinos-caracteristicas/hoteles-baratos-...
# 3                   POST /reserve-save2 HTTP/1.1" 200 72
# 4      GET /booking/8079/e/1/1?i=u4UVE31yWtwGGr3F7wsN...
# ...                                                  ...
# 11097                           GET / HTTP/1.1" 200 7528
# 11098                               HEAD / HTTP/1.1" 200
# 11099                            OPTIONS * HTTP/1.0" 200
# 11100                            OPTIONS * HTTP/1.0" 200
# 11101                            OPTIONS * HTTP/1.0" 200
#
#                                        Date  \
# 0                                        -"
# 1                                        -"
# 2                                        -"
# 3      http://www.akumenius.com/hotel-list"
# 4      http://www.akumenius.com/hotel-list"
# ...                                     ...
# 11097                                    -"
# 11098                                   "-"
# 11099                                   "-"
# 11100                                   "-"
# 11101                                   "-"
#
#                                                     Time Request  Status  \
# 0      Mozilla/5.0 (compatible; AhrefsBot/5.0; +http:...    None     NaN
# 1      Mozilla/5.0 (compatible; AhrefsBot/5.0; +http:...    None     NaN
# 2      Mozilla/5.0 (compatible; Googlebot/2.1; +http:...    None     NaN
# 3      Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...    None     NaN
# 4      Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...    None     NaN
# ...                                                  ...     ...     ...
# 11097  Mozilla/5.0 (compatible; YandexBot/3.0; +http:...    None     NaN
# 11098  Mozilla/5.0+(compatible; UptimeRobot/2.0; http...    None     NaN
# 11099         Apache (internal dummy connection)" VLOG=-    None     NaN
# 11100         Apache (internal dummy connection)" VLOG=-    None     NaN
# 11101         Apache (internal dummy connection)" VLOG=-    None     NaN
#
#        Size  Referer  UserAgent
# 0       NaN      NaN        NaN
# 1       NaN      NaN        NaN
# 2       NaN      NaN        NaN
# 3       NaN      NaN        NaN
# 4       NaN      NaN        NaN
# ...     ...      ...        ...
# 11097   NaN      NaN        NaN
# 11098   NaN      NaN        NaN
# 11099   NaN      NaN        NaN
# 11100   NaN      NaN        NaN
# 11101   NaN      NaN        NaN
#
# [11102 rows x 10 columns]

# %% [markdown]
# ###  Exercici 2
# - Neteja, preprocesa, estructura i transforma (dataframe) les dades del registre d'Accés a la web.

# %%
Logs.shape
# Out:
# (11102, 10)

# %%
Logs.isnull().sum()
# Out:
# DNS              0
# IP               0
# Location         0
# Date             0
# Time             0
# Request      10908
# Status       11102
# Size         11102
# Referer      11102
# UserAgent    11102
# dtype: int64

# %%
# Data sorting

Logs.UserAgent = Logs.Time
Logs.Request = Logs.Location
Logs.Referer = Logs.Date
Logs.Date = Logs.IP

Logs.head()
# Out:
#                               DNS                              IP  \
# 0    www.akumenius.com 5.10.83.86  - [01/Mar/2014:13:29:00 +0100]
# 1    www.akumenius.com 5.10.83.44  - [01/Mar/2014:13:29:00 +0100]
# 2  www.akumenius.com 66.249.64.98  - [01/Mar/2014:13:29:02 +0100]
# 3  www.akumenius.com 89.130.90.61  - [01/Mar/2014:13:29:06 +0100]
# 4  www.akumenius.com 89.130.90.61  - [01/Mar/2014:13:29:11 +0100]
#
#                                             Location  \
# 0  GET /destinosEstrelles/hoteles-en-Mykonos_GREC...
# 1  GET /destinos-baratos/hoteles-baratos/ofertas-...
# 2  GET /destinos-caracteristicas/hoteles-baratos-...
# 3               POST /reserve-save2 HTTP/1.1" 200 72
# 4  GET /booking/8079/e/1/1?i=u4UVE31yWtwGGr3F7wsN...
#
#                              Date  \
# 0  - [01/Mar/2014:13:29:00 +0100]
# 1  - [01/Mar/2014:13:29:00 +0100]
# 2  - [01/Mar/2014:13:29:02 +0100]
# 3  - [01/Mar/2014:13:29:06 +0100]
# 4  - [01/Mar/2014:13:29:11 +0100]
#
#                                                 Time  \
# 0  Mozilla/5.0 (compatible; AhrefsBot/5.0; +http:...
# 1  Mozilla/5.0 (compatible; AhrefsBot/5.0; +http:...
# 2  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 3  Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...
# 4  Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...
#
#                                              Request  Status  Size  \
# 0  GET /destinosEstrelles/hoteles-en-Mykonos_GREC...     NaN   NaN
# 1  GET /destinos-baratos/hoteles-baratos/ofertas-...     NaN   NaN
# 2  GET /destinos-caracteristicas/hoteles-baratos-...     NaN   NaN
# 3               POST /reserve-save2 HTTP/1.1" 200 72     NaN   NaN
# 4  GET /booking/8079/e/1/1?i=u4UVE31yWtwGGr3F7wsN...     NaN   NaN
#
#                                 Referer  \
# 0                                    -"
# 1                                    -"
# 2                                    -"
# 3  http://www.akumenius.com/hotel-list"
# 4  http://www.akumenius.com/hotel-list"
#
#                                            UserAgent
# 0  Mozilla/5.0 (compatible; AhrefsBot/5.0; +http:...
# 1  Mozilla/5.0 (compatible; AhrefsBot/5.0; +http:...
# 2  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 3  Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...
# 4  Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...

# %%
# DNS & IP data split

Logs[['DNS','IP']] = Logs.DNS.str.split('\s', expand = True).get([0,1])

# %%
Logs.head()
# Out:
#                  DNS            IP  \
# 0  www.akumenius.com    5.10.83.86
# 1  www.akumenius.com    5.10.83.44
# 2  www.akumenius.com  66.249.64.98
# 3  www.akumenius.com  89.130.90.61
# 4  www.akumenius.com  89.130.90.61
#
#                                             Location  \
# 0  GET /destinosEstrelles/hoteles-en-Mykonos_GREC...
# 1  GET /destinos-baratos/hoteles-baratos/ofertas-...
# 2  GET /destinos-caracteristicas/hoteles-baratos-...
# 3               POST /reserve-save2 HTTP/1.1" 200 72
# 4  GET /booking/8079/e/1/1?i=u4UVE31yWtwGGr3F7wsN...
#
#                              Date  \
# 0  - [01/Mar/2014:13:29:00 +0100]
# 1  - [01/Mar/2014:13:29:00 +0100]
# 2  - [01/Mar/2014:13:29:02 +0100]
# 3  - [01/Mar/2014:13:29:06 +0100]
# 4  - [01/Mar/2014:13:29:11 +0100]
#
#                                                 Time  \
# 0  Mozilla/5.0 (compatible; AhrefsBot/5.0; +http:...
# 1  Mozilla/5.0 (compatible; AhrefsBot/5.0; +http:...
# 2  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 3  Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...
# 4  Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...
#
#                                              Request  Status  Size  \
# 0  GET /destinosEstrelles/hoteles-en-Mykonos_GREC...     NaN   NaN
# 1  GET /destinos-baratos/hoteles-baratos/ofertas-...     NaN   NaN
# 2  GET /destinos-caracteristicas/hoteles-baratos-...     NaN   NaN
# 3               POST /reserve-save2 HTTP/1.1" 200 72     NaN   NaN
# 4  GET /booking/8079/e/1/1?i=u4UVE31yWtwGGr3F7wsN...     NaN   NaN
#
#                                 Referer  \
# 0                                    -"
# 1                                    -"
# 2                                    -"
# 3  http://www.akumenius.com/hotel-list"
# 4  http://www.akumenius.com/hotel-list"
#
#                                            UserAgent
# 0  Mozilla/5.0 (compatible; AhrefsBot/5.0; +http:...
# 1  Mozilla/5.0 (compatible; AhrefsBot/5.0; +http:...
# 2  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 3  Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...
# 4  Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...

# %%
Logs.DNS.unique()
# Out:
# array(['www.akumenius.com', 'localhost', 'akumenius.com',
#        'test.akumenius.com', 'akumenius.es'], dtype=object)

# %%
# Time data extraction

Logs.Time = Logs.Date.str.extract(':(\d{2}:\d{2}:\d{2}.*)]')

# %%
# Date data extraction

Logs.Date= Logs.Date.str.extract('(\d+/\w+/\d+)')

# %%
Logs.head()
# Out:
#                  DNS            IP  \
# 0  www.akumenius.com    5.10.83.86
# 1  www.akumenius.com    5.10.83.44
# 2  www.akumenius.com  66.249.64.98
# 3  www.akumenius.com  89.130.90.61
# 4  www.akumenius.com  89.130.90.61
#
#                                             Location         Date  \
# 0  GET /destinosEstrelles/hoteles-en-Mykonos_GREC...  01/Mar/2014
# 1  GET /destinos-baratos/hoteles-baratos/ofertas-...  01/Mar/2014
# 2  GET /destinos-caracteristicas/hoteles-baratos-...  01/Mar/2014
# 3               POST /reserve-save2 HTTP/1.1" 200 72  01/Mar/2014
# 4  GET /booking/8079/e/1/1?i=u4UVE31yWtwGGr3F7wsN...  01/Mar/2014
#
#              Time                                            Request  Status  \
# 0  13:29:00 +0100  GET /destinosEstrelles/hoteles-en-Mykonos_GREC...     NaN
# 1  13:29:00 +0100  GET /destinos-baratos/hoteles-baratos/ofertas-...     NaN
# 2  13:29:02 +0100  GET /destinos-caracteristicas/hoteles-baratos-...     NaN
# 3  13:29:06 +0100               POST /reserve-save2 HTTP/1.1" 200 72     NaN
# 4  13:29:11 +0100  GET /booking/8079/e/1/1?i=u4UVE31yWtwGGr3F7wsN...     NaN
#
#    Size                               Referer  \
# 0   NaN                                    -"
# 1   NaN                                    -"
# 2   NaN                                    -"
# 3   NaN  http://www.akumenius.com/hotel-list"
# 4   NaN  http://www.akumenius.com/hotel-list"
#
#                                            UserAgent
# 0  Mozilla/5.0 (compatible; AhrefsBot/5.0; +http:...
# 1  Mozilla/5.0 (compatible; AhrefsBot/5.0; +http:...
# 2  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 3  Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...
# 4  Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...

# %%
# Request & Status data split

Logs[['Request','Status']] = Logs.Request.str.split('\"', expand = True).get([0,1])

# %%
Logs.head()
# Out:
#                  DNS            IP  \
# 0  www.akumenius.com    5.10.83.86
# 1  www.akumenius.com    5.10.83.44
# 2  www.akumenius.com  66.249.64.98
# 3  www.akumenius.com  89.130.90.61
# 4  www.akumenius.com  89.130.90.61
#
#                                             Location         Date  \
# 0  GET /destinosEstrelles/hoteles-en-Mykonos_GREC...  01/Mar/2014
# 1  GET /destinos-baratos/hoteles-baratos/ofertas-...  01/Mar/2014
# 2  GET /destinos-caracteristicas/hoteles-baratos-...  01/Mar/2014
# 3               POST /reserve-save2 HTTP/1.1" 200 72  01/Mar/2014
# 4  GET /booking/8079/e/1/1?i=u4UVE31yWtwGGr3F7wsN...  01/Mar/2014
#
#              Time                                            Request  \
# 0  13:29:00 +0100  GET /destinosEstrelles/hoteles-en-Mykonos_GREC...
# 1  13:29:00 +0100  GET /destinos-baratos/hoteles-baratos/ofertas-...
# 2  13:29:02 +0100  GET /destinos-caracteristicas/hoteles-baratos-...
# 3  13:29:06 +0100                       POST /reserve-save2 HTTP/1.1
# 4  13:29:11 +0100  GET /booking/8079/e/1/1?i=u4UVE31yWtwGGr3F7wsN...
#
#        Status  Size                               Referer  \
# 0   200 17523   NaN                                    -"
# 1    200 5562   NaN                                    -"
# 2    200 8072   NaN                                    -"
# 3      200 72   NaN  http://www.akumenius.com/hotel-list"
# 4   200 11204   NaN  http://www.akumenius.com/hotel-list"
#
#                                            UserAgent
# 0  Mozilla/5.0 (compatible; AhrefsBot/5.0; +http:...
# 1  Mozilla/5.0 (compatible; AhrefsBot/5.0; +http:...
# 2  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 3  Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...
# 4  Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...

# %%
# Size data extraction

Logs.Size = Logs.Status.str.extract('(\d+$)')
Logs.head()
# Out:
#                  DNS            IP  \
# 0  www.akumenius.com    5.10.83.86
# 1  www.akumenius.com    5.10.83.44
# 2  www.akumenius.com  66.249.64.98
# 3  www.akumenius.com  89.130.90.61
# 4  www.akumenius.com  89.130.90.61
#
#                                             Location         Date  \
# 0  GET /destinosEstrelles/hoteles-en-Mykonos_GREC...  01/Mar/2014
# 1  GET /destinos-baratos/hoteles-baratos/ofertas-...  01/Mar/2014
# 2  GET /destinos-caracteristicas/hoteles-baratos-...  01/Mar/2014
# 3               POST /reserve-save2 HTTP/1.1" 200 72  01/Mar/2014
# 4  GET /booking/8079/e/1/1?i=u4UVE31yWtwGGr3F7wsN...  01/Mar/2014
#
#              Time                                            Request  \
# 0  13:29:00 +0100  GET /destinosEstrelles/hoteles-en-Mykonos_GREC...
# 1  13:29:00 +0100  GET /destinos-baratos/hoteles-baratos/ofertas-...
# 2  13:29:02 +0100  GET /destinos-caracteristicas/hoteles-baratos-...
# 3  13:29:06 +0100                       POST /reserve-save2 HTTP/1.1
# 4  13:29:11 +0100  GET /booking/8079/e/1/1?i=u4UVE31yWtwGGr3F7wsN...
#
#        Status   Size                               Referer  \
# 0   200 17523  17523                                    -"
# 1    200 5562   5562                                    -"
# 2    200 8072   8072                                    -"
# 3      200 72     72  http://www.akumenius.com/hotel-list"
# 4   200 11204  11204  http://www.akumenius.com/hotel-list"
#
#                                            UserAgent
# 0  Mozilla/5.0 (compatible; AhrefsBot/5.0; +http:...
# 1  Mozilla/5.0 (compatible; AhrefsBot/5.0; +http:...
# 2  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 3  Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...
# 4  Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...

# %%
# Status data extraction

Logs.Status = Logs.Status.str.extract('(\d{3})')
Logs.head()
# Out:
#                  DNS            IP  \
# 0  www.akumenius.com    5.10.83.86
# 1  www.akumenius.com    5.10.83.44
# 2  www.akumenius.com  66.249.64.98
# 3  www.akumenius.com  89.130.90.61
# 4  www.akumenius.com  89.130.90.61
#
#                                             Location         Date  \
# 0  GET /destinosEstrelles/hoteles-en-Mykonos_GREC...  01/Mar/2014
# 1  GET /destinos-baratos/hoteles-baratos/ofertas-...  01/Mar/2014
# 2  GET /destinos-caracteristicas/hoteles-baratos-...  01/Mar/2014
# 3               POST /reserve-save2 HTTP/1.1" 200 72  01/Mar/2014
# 4  GET /booking/8079/e/1/1?i=u4UVE31yWtwGGr3F7wsN...  01/Mar/2014
#
#              Time                                            Request Status  \
# 0  13:29:00 +0100  GET /destinosEstrelles/hoteles-en-Mykonos_GREC...    200
# 1  13:29:00 +0100  GET /destinos-baratos/hoteles-baratos/ofertas-...    200
# 2  13:29:02 +0100  GET /destinos-caracteristicas/hoteles-baratos-...    200
# 3  13:29:06 +0100                       POST /reserve-save2 HTTP/1.1    200
# 4  13:29:11 +0100  GET /booking/8079/e/1/1?i=u4UVE31yWtwGGr3F7wsN...    200
#
#     Size                               Referer  \
# 0  17523                                    -"
# 1   5562                                    -"
# 2   8072                                    -"
# 3     72  http://www.akumenius.com/hotel-list"
# 4  11204  http://www.akumenius.com/hotel-list"
#
#                                            UserAgent
# 0  Mozilla/5.0 (compatible; AhrefsBot/5.0; +http:...
# 1  Mozilla/5.0 (compatible; AhrefsBot/5.0; +http:...
# 2  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 3  Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...
# 4  Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...

# %%
# Referer useless data correction

for index, row in Logs.iterrows(): 
    
    if row.Referer == '"-"' or row.Referer == '-"':
        row.Referer = np.nan
        
Logs.head()
# Out:
#                  DNS            IP  \
# 0  www.akumenius.com    5.10.83.86
# 1  www.akumenius.com    5.10.83.44
# 2  www.akumenius.com  66.249.64.98
# 3  www.akumenius.com  89.130.90.61
# 4  www.akumenius.com  89.130.90.61
#
#                                             Location         Date  \
# 0  GET /destinosEstrelles/hoteles-en-Mykonos_GREC...  01/Mar/2014
# 1  GET /destinos-baratos/hoteles-baratos/ofertas-...  01/Mar/2014
# 2  GET /destinos-caracteristicas/hoteles-baratos-...  01/Mar/2014
# 3               POST /reserve-save2 HTTP/1.1" 200 72  01/Mar/2014
# 4  GET /booking/8079/e/1/1?i=u4UVE31yWtwGGr3F7wsN...  01/Mar/2014
#
#              Time                                            Request Status  \
# 0  13:29:00 +0100  GET /destinosEstrelles/hoteles-en-Mykonos_GREC...    200
# 1  13:29:00 +0100  GET /destinos-baratos/hoteles-baratos/ofertas-...    200
# 2  13:29:02 +0100  GET /destinos-caracteristicas/hoteles-baratos-...    200
# 3  13:29:06 +0100                       POST /reserve-save2 HTTP/1.1    200
# 4  13:29:11 +0100  GET /booking/8079/e/1/1?i=u4UVE31yWtwGGr3F7wsN...    200
#
#     Size                               Referer  \
# 0  17523                                   NaN
# 1   5562                                   NaN
# 2   8072                                   NaN
# 3     72  http://www.akumenius.com/hotel-list"
# 4  11204  http://www.akumenius.com/hotel-list"
#
#                                            UserAgent
# 0  Mozilla/5.0 (compatible; AhrefsBot/5.0; +http:...
# 1  Mozilla/5.0 (compatible; AhrefsBot/5.0; +http:...
# 2  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 3  Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...
# 4  Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...

# %% [markdown]
# ###  Exercici 3
# - Geolocalitza les IP's. Aqui tens una pagina de interes:
#   - [IP2Locattion](https://blog.ip2location.com/knowledge-base/how-to-add-a-sub-account-in-ip2location/)

# %%
import json
from ip2geotools.databases.noncommercial import DbIpCity

# %%
# Extract Ips

Ips = Logs.IP.unique()

# %%
# Function for extract Locations

localhost = "127.0.0.1"

def location(ip):
    
    try:
        if ip == localhost:
            return ('Local', 'Local')

        else:
            response = DbIpCity.get(ip, api_key = 'free').to_json()    
            data = json.loads(response)
            return data['city'], data['country']
    
    except:
        return np.nan

# %%
# Extract Location Test

location(Logs.IP[0])
# Out:
# ('Amsterdam', 'NL')

# %%
# List of locations for unique Ips

Location = []

for element in Ips:
    
    Location.append(location(element))

# %%
# Compare ips & add location

for index, row in Logs.iterrows(): 
    
    # iterate the two lists
    for a, b in zip(Ips, Location):
        
        # Compare & add
        if row.IP == a:
            row.Location = b

# %%
Logs.head()
# Out:
#                  DNS            IP                  Location         Date  \
# 0  www.akumenius.com    5.10.83.86           (Amsterdam, NL)  01/Mar/2014
# 1  www.akumenius.com    5.10.83.44   (Stockholm (Kista), SE)  01/Mar/2014
# 2  www.akumenius.com  66.249.64.98       (Mountain View, US)  01/Mar/2014
# 3  www.akumenius.com  89.130.90.61  (Pozuelo de Alarcón, ES)  01/Mar/2014
# 4  www.akumenius.com  89.130.90.61  (Pozuelo de Alarcón, ES)  01/Mar/2014
#
#              Time                                            Request Status  \
# 0  13:29:00 +0100  GET /destinosEstrelles/hoteles-en-Mykonos_GREC...    200
# 1  13:29:00 +0100  GET /destinos-baratos/hoteles-baratos/ofertas-...    200
# 2  13:29:02 +0100  GET /destinos-caracteristicas/hoteles-baratos-...    200
# 3  13:29:06 +0100                       POST /reserve-save2 HTTP/1.1    200
# 4  13:29:11 +0100  GET /booking/8079/e/1/1?i=u4UVE31yWtwGGr3F7wsN...    200
#
#     Size                               Referer  \
# 0  17523                                   NaN
# 1   5562                                   NaN
# 2   8072                                   NaN
# 3     72  http://www.akumenius.com/hotel-list"
# 4  11204  http://www.akumenius.com/hotel-list"
#
#                                            UserAgent
# 0  Mozilla/5.0 (compatible; AhrefsBot/5.0; +http:...
# 1  Mozilla/5.0 (compatible; AhrefsBot/5.0; +http:...
# 2  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 3  Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...
# 4  Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...

# %% [markdown]
# ###  Exercici 4
# - Mostreu-me la teva creativitat, Sorprèn-me fes un pas més enllà amb el analysis anterior.

# %% [markdown]
# #### En proceso
