# %% [markdown]
# # IT Academy - Data Science amb Python
# ## Tasca 7: Estructura de control
#
# ###  [Github Registre de Logs](https://github.com/jesussantana/Registre_de_logs)

# %% [markdown]
# ###  Exercici 1
# - Normalitza, identifica i enumera cada un dels atributs / variables de l'estructura de l'arxiu "Web_access_log-akumenius.com" que trobaràs al repositori de GitHub "Data-sources".

# %%
import numpy as np
import pandas as pd
import requests
import re

pd.set_option('display.max_columns', None)

# %%
path = '../Data/Web_access_log-akumenius.com.txt'

Logs = pd.read_csv(path, sep='\s | \- | \"', names =['DNS','IP','Location','Date','Time','Request','Status','Size','Referer','UserAgent'], skiprows=261771, engine='python')

Logs
# Out:
#                                  DNS                              IP  \
# 0    www.akumenius.com 79.155.78.117  - [02/Mar/2014:02:30:23 +0100]
# 1    www.akumenius.com 79.155.78.117  - [02/Mar/2014:02:30:23 +0100]
# 2    www.akumenius.com 79.155.78.117  - [02/Mar/2014:02:30:23 +0100]
# 3    www.akumenius.com 79.155.78.117  - [02/Mar/2014:02:30:23 +0100]
# 4    www.akumenius.com 79.155.78.117  - [02/Mar/2014:02:30:23 +0100]
# ..                               ...                             ...
# 97    www.akumenius.com 5.255.253.53  - [02/Mar/2014:03:05:39 +0100]
# 98   www.akumenius.com 74.86.158.107  - [02/Mar/2014:03:09:52 +0100]
# 99               localhost 127.0.0.1  - [02/Mar/2014:03:10:18 +0100]
# 100              localhost 127.0.0.1  - [02/Mar/2014:03:10:18 +0100]
# 101              localhost 127.0.0.1  - [02/Mar/2014:03:10:18 +0100]
#
#                                               Location  \
# 0    GET /modules/raton/views/themes/bcoos/images/F...
# 1    GET /modules/raton/views/themes/bcoos/images/b...
# 2    GET /modules/raton/views/themes/bcoos/images/F...
# 3    GET /modules/raton/views/themes/bcoos/images/b...
# 4    GET /modules/raton/views/themes/bcoos/images/b...
# ..                                                 ...
# 97                            GET / HTTP/1.1" 200 7528
# 98                                HEAD / HTTP/1.1" 200
# 99                             OPTIONS * HTTP/1.0" 200
# 100                            OPTIONS * HTTP/1.0" 200
# 101                            OPTIONS * HTTP/1.0" 200
#
#                                                   Date  \
# 0    http://www.akumenius.com/destinos-baratos/dest...
# 1    http://www.akumenius.com/destinos-baratos/dest...
# 2    http://www.akumenius.com/destinos-baratos/dest...
# 3    http://www.akumenius.com/destinos-baratos/dest...
# 4    http://www.akumenius.com/destinos-baratos/dest...
# ..                                                 ...
# 97                                                  -"
# 98                                                 "-"
# 99                                                 "-"
# 100                                                "-"
# 101                                                "-"
#
#                                                   Time  Request  Status  Size  \
# 0    Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...      NaN     NaN   NaN
# 1    Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...      NaN     NaN   NaN
# 2    Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...      NaN     NaN   NaN
# 3    Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...      NaN     NaN   NaN
# 4    Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...      NaN     NaN   NaN
# ..                                                 ...      ...     ...   ...
# 97   Mozilla/5.0 (compatible; YandexBot/3.0; +http:...      NaN     NaN   NaN
# 98   Mozilla/5.0+(compatible; UptimeRobot/2.0; http...      NaN     NaN   NaN
# 99          Apache (internal dummy connection)" VLOG=-      NaN     NaN   NaN
# 100         Apache (internal dummy connection)" VLOG=-      NaN     NaN   NaN
# 101         Apache (internal dummy connection)" VLOG=-      NaN     NaN   NaN
#
#      Referer  UserAgent
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN
# ..       ...        ...
# 97       NaN        NaN
# 98       NaN        NaN
# 99       NaN        NaN
# 100      NaN        NaN
# 101      NaN        NaN
#
# [102 rows x 10 columns]

# %% [markdown]
# ###  Exercici 2
# - Neteja, preprocesa, estructura i transforma (dataframe) les dades del registre d'Accés a la web.

# %%
Logs.shape
# Out:
# (102, 10)

# %%
Logs.isnull().sum()
# Out:
# DNS            0
# IP             0
# Location       0
# Date           0
# Time           0
# Request      102
# Status       102
# Size         102
# Referer      102
# UserAgent    102
# dtype: int64

# %%
Logs.head()
# Out:
#                                DNS                              IP  \
# 0  www.akumenius.com 79.155.78.117  - [02/Mar/2014:02:30:23 +0100]
# 1  www.akumenius.com 79.155.78.117  - [02/Mar/2014:02:30:23 +0100]
# 2  www.akumenius.com 79.155.78.117  - [02/Mar/2014:02:30:23 +0100]
# 3  www.akumenius.com 79.155.78.117  - [02/Mar/2014:02:30:23 +0100]
# 4  www.akumenius.com 79.155.78.117  - [02/Mar/2014:02:30:23 +0100]
#
#                                             Location  \
# 0  GET /modules/raton/views/themes/bcoos/images/F...
# 1  GET /modules/raton/views/themes/bcoos/images/b...
# 2  GET /modules/raton/views/themes/bcoos/images/F...
# 3  GET /modules/raton/views/themes/bcoos/images/b...
# 4  GET /modules/raton/views/themes/bcoos/images/b...
#
#                                                 Date  \
# 0  http://www.akumenius.com/destinos-baratos/dest...
# 1  http://www.akumenius.com/destinos-baratos/dest...
# 2  http://www.akumenius.com/destinos-baratos/dest...
# 3  http://www.akumenius.com/destinos-baratos/dest...
# 4  http://www.akumenius.com/destinos-baratos/dest...
#
#                                                 Time  Request  Status  Size  \
# 0  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...      NaN     NaN   NaN
# 1  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...      NaN     NaN   NaN
# 2  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...      NaN     NaN   NaN
# 3  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...      NaN     NaN   NaN
# 4  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...      NaN     NaN   NaN
#
#    Referer  UserAgent
# 0      NaN        NaN
# 1      NaN        NaN
# 2      NaN        NaN
# 3      NaN        NaN
# 4      NaN        NaN

# %%
# Reorder columns of data

Logs.UserAgent = Logs.Time
Logs.Request = Logs.Location
Logs.Referer = Logs.Date
Logs.Date = Logs.IP
Logs.Time = Logs.IP = np.nan
Logs.Location = ""

Logs.head()
# Out:
#                                DNS  IP Location  \
# 0  www.akumenius.com 79.155.78.117 NaN
# 1  www.akumenius.com 79.155.78.117 NaN
# 2  www.akumenius.com 79.155.78.117 NaN
# 3  www.akumenius.com 79.155.78.117 NaN
# 4  www.akumenius.com 79.155.78.117 NaN
#
#                              Date  Time  \
# 0  - [02/Mar/2014:02:30:23 +0100]   NaN
# 1  - [02/Mar/2014:02:30:23 +0100]   NaN
# 2  - [02/Mar/2014:02:30:23 +0100]   NaN
# 3  - [02/Mar/2014:02:30:23 +0100]   NaN
# 4  - [02/Mar/2014:02:30:23 +0100]   NaN
#
#                                              Request  Status  Size  \
# 0  GET /modules/raton/views/themes/bcoos/images/F...     NaN   NaN
# 1  GET /modules/raton/views/themes/bcoos/images/b...     NaN   NaN
# 2  GET /modules/raton/views/themes/bcoos/images/F...     NaN   NaN
# 3  GET /modules/raton/views/themes/bcoos/images/b...     NaN   NaN
# 4  GET /modules/raton/views/themes/bcoos/images/b...     NaN   NaN
#
#                                              Referer  \
# 0  http://www.akumenius.com/destinos-baratos/dest...
# 1  http://www.akumenius.com/destinos-baratos/dest...
# 2  http://www.akumenius.com/destinos-baratos/dest...
# 3  http://www.akumenius.com/destinos-baratos/dest...
# 4  http://www.akumenius.com/destinos-baratos/dest...
#
#                                            UserAgent
# 0  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 1  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 2  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 3  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 4  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...

# %%
# DNS & IP data split

Logs[['DNS','IP']] = Logs.DNS.str.split('\s', expand = True).get([0, 1])

# %%
Logs.head()
# Out:
#                  DNS             IP Location                            Date  \
# 0  www.akumenius.com  79.155.78.117           - [02/Mar/2014:02:30:23 +0100]
# 1  www.akumenius.com  79.155.78.117           - [02/Mar/2014:02:30:23 +0100]
# 2  www.akumenius.com  79.155.78.117           - [02/Mar/2014:02:30:23 +0100]
# 3  www.akumenius.com  79.155.78.117           - [02/Mar/2014:02:30:23 +0100]
# 4  www.akumenius.com  79.155.78.117           - [02/Mar/2014:02:30:23 +0100]
#
#    Time                                            Request  Status  Size  \
# 0   NaN  GET /modules/raton/views/themes/bcoos/images/F...     NaN   NaN
# 1   NaN  GET /modules/raton/views/themes/bcoos/images/b...     NaN   NaN
# 2   NaN  GET /modules/raton/views/themes/bcoos/images/F...     NaN   NaN
# 3   NaN  GET /modules/raton/views/themes/bcoos/images/b...     NaN   NaN
# 4   NaN  GET /modules/raton/views/themes/bcoos/images/b...     NaN   NaN
#
#                                              Referer  \
# 0  http://www.akumenius.com/destinos-baratos/dest...
# 1  http://www.akumenius.com/destinos-baratos/dest...
# 2  http://www.akumenius.com/destinos-baratos/dest...
# 3  http://www.akumenius.com/destinos-baratos/dest...
# 4  http://www.akumenius.com/destinos-baratos/dest...
#
#                                            UserAgent
# 0  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 1  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 2  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 3  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 4  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...

# %%
Logs.DNS.unique()
# Out:
# array(['www.akumenius.com', 'localhost', 'akumenius.com', 'akumenius.es'],
#       dtype=object)

# %%
# Time data extraction

Logs.Time = Logs.Date.str.extract(':(\d{2}:\d{2}:\d{2}.*)]')

# %%
# Date data extraction

Logs.Date= Logs.Date.str.extract('(\d+/\w+/\d+)')

# %%
Logs.head()
# Out:
#                  DNS             IP Location         Date            Time  \
# 0  www.akumenius.com  79.155.78.117           02/Mar/2014  02:30:23 +0100
# 1  www.akumenius.com  79.155.78.117           02/Mar/2014  02:30:23 +0100
# 2  www.akumenius.com  79.155.78.117           02/Mar/2014  02:30:23 +0100
# 3  www.akumenius.com  79.155.78.117           02/Mar/2014  02:30:23 +0100
# 4  www.akumenius.com  79.155.78.117           02/Mar/2014  02:30:23 +0100
#
#                                              Request  Status  Size  \
# 0  GET /modules/raton/views/themes/bcoos/images/F...     NaN   NaN
# 1  GET /modules/raton/views/themes/bcoos/images/b...     NaN   NaN
# 2  GET /modules/raton/views/themes/bcoos/images/F...     NaN   NaN
# 3  GET /modules/raton/views/themes/bcoos/images/b...     NaN   NaN
# 4  GET /modules/raton/views/themes/bcoos/images/b...     NaN   NaN
#
#                                              Referer  \
# 0  http://www.akumenius.com/destinos-baratos/dest...
# 1  http://www.akumenius.com/destinos-baratos/dest...
# 2  http://www.akumenius.com/destinos-baratos/dest...
# 3  http://www.akumenius.com/destinos-baratos/dest...
# 4  http://www.akumenius.com/destinos-baratos/dest...
#
#                                            UserAgent
# 0  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 1  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 2  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 3  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 4  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...

# %%
# Request & Status data split

Logs[['Request','Status']] = Logs.Request.str.split('\"', expand = True).get([0, 1])

# %%
Logs.head()
# Out:
#                  DNS             IP Location         Date            Time  \
# 0  www.akumenius.com  79.155.78.117           02/Mar/2014  02:30:23 +0100
# 1  www.akumenius.com  79.155.78.117           02/Mar/2014  02:30:23 +0100
# 2  www.akumenius.com  79.155.78.117           02/Mar/2014  02:30:23 +0100
# 3  www.akumenius.com  79.155.78.117           02/Mar/2014  02:30:23 +0100
# 4  www.akumenius.com  79.155.78.117           02/Mar/2014  02:30:23 +0100
#
#                                              Request     Status  Size  \
# 0  GET /modules/raton/views/themes/bcoos/images/F...   200 1169   NaN
# 1  GET /modules/raton/views/themes/bcoos/images/b...   200 2167   NaN
# 2  GET /modules/raton/views/themes/bcoos/images/F...   200 1047   NaN
# 3  GET /modules/raton/views/themes/bcoos/images/b...   200 2540   NaN
# 4  GET /modules/raton/views/themes/bcoos/images/b...    200 614   NaN
#
#                                              Referer  \
# 0  http://www.akumenius.com/destinos-baratos/dest...
# 1  http://www.akumenius.com/destinos-baratos/dest...
# 2  http://www.akumenius.com/destinos-baratos/dest...
# 3  http://www.akumenius.com/destinos-baratos/dest...
# 4  http://www.akumenius.com/destinos-baratos/dest...
#
#                                            UserAgent
# 0  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 1  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 2  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 3  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 4  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...

# %%
# Size data extraction

Logs.Size = Logs.Status.str.extract('(\d+$)')
Logs.head()
# Out:
#                  DNS             IP Location         Date            Time  \
# 0  www.akumenius.com  79.155.78.117           02/Mar/2014  02:30:23 +0100
# 1  www.akumenius.com  79.155.78.117           02/Mar/2014  02:30:23 +0100
# 2  www.akumenius.com  79.155.78.117           02/Mar/2014  02:30:23 +0100
# 3  www.akumenius.com  79.155.78.117           02/Mar/2014  02:30:23 +0100
# 4  www.akumenius.com  79.155.78.117           02/Mar/2014  02:30:23 +0100
#
#                                              Request     Status  Size  \
# 0  GET /modules/raton/views/themes/bcoos/images/F...   200 1169  1169
# 1  GET /modules/raton/views/themes/bcoos/images/b...   200 2167  2167
# 2  GET /modules/raton/views/themes/bcoos/images/F...   200 1047  1047
# 3  GET /modules/raton/views/themes/bcoos/images/b...   200 2540  2540
# 4  GET /modules/raton/views/themes/bcoos/images/b...    200 614   614
#
#                                              Referer  \
# 0  http://www.akumenius.com/destinos-baratos/dest...
# 1  http://www.akumenius.com/destinos-baratos/dest...
# 2  http://www.akumenius.com/destinos-baratos/dest...
# 3  http://www.akumenius.com/destinos-baratos/dest...
# 4  http://www.akumenius.com/destinos-baratos/dest...
#
#                                            UserAgent
# 0  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 1  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 2  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 3  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 4  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...

# %%
# Status data extraction

Logs.Status = Logs.Status.str.extract('(\d{3})')
Logs.head()
# Out:
#                  DNS             IP Location         Date            Time  \
# 0  www.akumenius.com  79.155.78.117           02/Mar/2014  02:30:23 +0100
# 1  www.akumenius.com  79.155.78.117           02/Mar/2014  02:30:23 +0100
# 2  www.akumenius.com  79.155.78.117           02/Mar/2014  02:30:23 +0100
# 3  www.akumenius.com  79.155.78.117           02/Mar/2014  02:30:23 +0100
# 4  www.akumenius.com  79.155.78.117           02/Mar/2014  02:30:23 +0100
#
#                                              Request Status  Size  \
# 0  GET /modules/raton/views/themes/bcoos/images/F...    200  1169
# 1  GET /modules/raton/views/themes/bcoos/images/b...    200  2167
# 2  GET /modules/raton/views/themes/bcoos/images/F...    200  1047
# 3  GET /modules/raton/views/themes/bcoos/images/b...    200  2540
# 4  GET /modules/raton/views/themes/bcoos/images/b...    200   614
#
#                                              Referer  \
# 0  http://www.akumenius.com/destinos-baratos/dest...
# 1  http://www.akumenius.com/destinos-baratos/dest...
# 2  http://www.akumenius.com/destinos-baratos/dest...
# 3  http://www.akumenius.com/destinos-baratos/dest...
# 4  http://www.akumenius.com/destinos-baratos/dest...
#
#                                            UserAgent
# 0  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 1  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 2  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 3  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 4  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...

# %%
# Referer useless data correction

for index, row in Logs.iterrows(): 
    
    if row.Referer == '"-"' or row.Referer == '-"':
        row.Referer = ""
                
Logs
# Out:
#                    DNS             IP Location         Date            Time  \
# 0    www.akumenius.com  79.155.78.117           02/Mar/2014  02:30:23 +0100
# 1    www.akumenius.com  79.155.78.117           02/Mar/2014  02:30:23 +0100
# 2    www.akumenius.com  79.155.78.117           02/Mar/2014  02:30:23 +0100
# 3    www.akumenius.com  79.155.78.117           02/Mar/2014  02:30:23 +0100
# 4    www.akumenius.com  79.155.78.117           02/Mar/2014  02:30:23 +0100
# ..                 ...            ...      ...          ...             ...
# 97   www.akumenius.com   5.255.253.53           02/Mar/2014  03:05:39 +0100
# 98   www.akumenius.com  74.86.158.107           02/Mar/2014  03:09:52 +0100
# 99           localhost      127.0.0.1           02/Mar/2014  03:10:18 +0100
# 100          localhost      127.0.0.1           02/Mar/2014  03:10:18 +0100
# 101          localhost      127.0.0.1           02/Mar/2014  03:10:18 +0100
#
#                                                Request Status  Size  \
# 0    GET /modules/raton/views/themes/bcoos/images/F...    200  1169
# 1    GET /modules/raton/views/themes/bcoos/images/b...    200  2167
# 2    GET /modules/raton/views/themes/bcoos/images/F...    200  1047
# 3    GET /modules/raton/views/themes/bcoos/images/b...    200  2540
# 4    GET /modules/raton/views/themes/bcoos/images/b...    200   614
# ..                                                 ...    ...   ...
# 97                                      GET / HTTP/1.1    200  7528
# 98                                     HEAD / HTTP/1.1    200   200
# 99                                  OPTIONS * HTTP/1.0    200   200
# 100                                 OPTIONS * HTTP/1.0    200   200
# 101                                 OPTIONS * HTTP/1.0    200   200
#
#                                                Referer  \
# 0    http://www.akumenius.com/destinos-baratos/dest...
# 1    http://www.akumenius.com/destinos-baratos/dest...
# 2    http://www.akumenius.com/destinos-baratos/dest...
# 3    http://www.akumenius.com/destinos-baratos/dest...
# 4    http://www.akumenius.com/destinos-baratos/dest...
# ..                                                 ...
# 97
# 98
# 99
# 100
# 101
#
#                                              UserAgent
# 0    Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 1    Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 2    Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 3    Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 4    Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# ..                                                 ...
# 97   Mozilla/5.0 (compatible; YandexBot/3.0; +http:...
# 98   Mozilla/5.0+(compatible; UptimeRobot/2.0; http...
# 99          Apache (internal dummy connection)" VLOG=-
# 100         Apache (internal dummy connection)" VLOG=-
# 101         Apache (internal dummy connection)" VLOG=-
#
# [102 rows x 10 columns]

# %% [markdown]
# ###  Exercici 3
# - Geolocalitza les IP's. Aqui tens una pagina de interes:
#   - [IP2Locattion](https://blog.ip2location.com/knowledge-base/how-to-add-a-sub-account-in-ip2location/)

# %%
import json
from ip2geotools.databases.noncommercial import DbIpCity

# %%
# Extract Ips

ips = Logs.IP.unique()
ips
# Out:
# array(['79.155.78.117', '127.0.0.1', '176.31.255.177', '66.249.76.216',
#        '157.55.32.185', '74.86.158.106', '194.30.26.30',
#        '217.174.248.179', '217.12.28.5', '157.55.34.173', '74.86.158.107',
#        '180.76.5.200', '157.56.92.174', '217.12.28.130', '188.135.173.80',
#        '180.76.6.37', '180.76.5.78', '83.45.25.198', '220.181.108.104',
#        '123.125.71.52', '66.249.75.148', '206.198.5.33', '5.255.253.53'],
#       dtype=object)

# %%
# Function for extract Locations

localhost = "127.0.0.1"

def extract_location(ip):
    
    try:
        if ip == localhost:
            return ('Local', 'Local')

        else:
            response = DbIpCity.get(ip, api_key = 'free').to_json()    
            data = json.loads(response)
            return data['city'], data['country']
    
    except:
        return np.nan

# %%
# Extract Location Test

extract_location(Logs.IP[50])
# Out:
# ('Beijing', 'CN')

# %%
# List of locations for unique Ips

locations = []

for element in ips:
    
    locations.append(extract_location(element))  

locations
# Out:
# [('San Cristóbal de La Laguna', 'ES'),
#  ('Local', 'Local'),
#  ('Roubaix', 'FR'),
#  ('Mountain View', 'US'),
#  ('Newark', 'US'),
#  ('Chicago', 'US'),
#  ('Ceuta', 'ES'),
#  ('Gloucester', 'GB'),
#  ('Seville', 'ES'),
#  ('Newark', 'US'),
#  ('Chicago', 'US'),
#  ('Beijing', 'CN'),
#  ('Newark', 'US'),
#  ('Seville', 'ES'),
#  ('Lecce', 'IT'),
#  ('Beijing', 'CN'),
#  ('Beijing', 'CN'),
#  ('Madrid', 'ES'),
#  ('Beijing', 'CN'),
#  ('Haidian (Haidian Qu)', 'CN'),
#  ('Mountain View', 'US'),
#  ('Lincolnshire', 'US'),
#  ('Moscow (Tsentralnyy administrativnyy okrug)', 'RU')]

# %%
# Compare ips & add location

for index, row in Logs.iterrows():
    
    # iterate the two lists
    for a, b in zip(ips, locations):
        
        # Compare & add
        if row.IP == a:
            row.Location = b

# %%
Logs
# Out:
#                    DNS             IP  \
# 0    www.akumenius.com  79.155.78.117
# 1    www.akumenius.com  79.155.78.117
# 2    www.akumenius.com  79.155.78.117
# 3    www.akumenius.com  79.155.78.117
# 4    www.akumenius.com  79.155.78.117
# ..                 ...            ...
# 97   www.akumenius.com   5.255.253.53
# 98   www.akumenius.com  74.86.158.107
# 99           localhost      127.0.0.1
# 100          localhost      127.0.0.1
# 101          localhost      127.0.0.1
#
#                                               Location         Date  \
# 0                     (San Cristóbal de La Laguna, ES)  02/Mar/2014
# 1                     (San Cristóbal de La Laguna, ES)  02/Mar/2014
# 2                     (San Cristóbal de La Laguna, ES)  02/Mar/2014
# 3                     (San Cristóbal de La Laguna, ES)  02/Mar/2014
# 4                     (San Cristóbal de La Laguna, ES)  02/Mar/2014
# ..                                                 ...          ...
# 97   (Moscow (Tsentralnyy administrativnyy okrug), RU)  02/Mar/2014
# 98                                       (Chicago, US)  02/Mar/2014
# 99                                      (Local, Local)  02/Mar/2014
# 100                                     (Local, Local)  02/Mar/2014
# 101                                     (Local, Local)  02/Mar/2014
#
#                Time                                            Request Status  \
# 0    02:30:23 +0100  GET /modules/raton/views/themes/bcoos/images/F...    200
# 1    02:30:23 +0100  GET /modules/raton/views/themes/bcoos/images/b...    200
# 2    02:30:23 +0100  GET /modules/raton/views/themes/bcoos/images/F...    200
# 3    02:30:23 +0100  GET /modules/raton/views/themes/bcoos/images/b...    200
# 4    02:30:23 +0100  GET /modules/raton/views/themes/bcoos/images/b...    200
# ..              ...                                                ...    ...
# 97   03:05:39 +0100                                     GET / HTTP/1.1    200
# 98   03:09:52 +0100                                    HEAD / HTTP/1.1    200
# 99   03:10:18 +0100                                 OPTIONS * HTTP/1.0    200
# 100  03:10:18 +0100                                 OPTIONS * HTTP/1.0    200
# 101  03:10:18 +0100                                 OPTIONS * HTTP/1.0    200
#
#      Size                                            Referer  \
# 0    1169  http://www.akumenius.com/destinos-baratos/dest...
# 1    2167  http://www.akumenius.com/destinos-baratos/dest...
# 2    1047  http://www.akumenius.com/destinos-baratos/dest...
# 3    2540  http://www.akumenius.com/destinos-baratos/dest...
# 4     614  http://www.akumenius.com/destinos-baratos/dest...
# ..    ...                                                ...
# 97   7528
# 98    200
# 99    200
# 100   200
# 101   200
#
#                                              UserAgent
# 0    Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 1    Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 2    Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 3    Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 4    Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# ..                                                 ...
# 97   Mozilla/5.0 (compatible; YandexBot/3.0; +http:...
# 98   Mozilla/5.0+(compatible; UptimeRobot/2.0; http...
# 99          Apache (internal dummy connection)" VLOG=-
# 100         Apache (internal dummy connection)" VLOG=-
# 101         Apache (internal dummy connection)" VLOG=-
#
# [102 rows x 10 columns]

# %% [markdown]
# ###  Exercici 4
# - Mostreu-me la teva creativitat, Sorprèn-me fes un pas més enllà amb el analysis anterior.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
graph = Logs[['DNS', 'Date']].groupby(['DNS']).count().sort_values(by='Date',ascending=False)
graph = graph.rename(columns={'Date' : 'Frequency'})
graph.plot.bar(y = 'Frequency', color = 'green', ylabel = 'Frequency', legend = None, figsize = (10,6))
plt.show()

# %%
Logs.DNS.value_counts(ascending = True).plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='DNS'>

# %%
graph = Logs[['Status', 'Date']].groupby(['Status']).count().sort_values(by = 'Date',ascending = False)
graph = graph.rename(columns={'Date' : 'Frequency'})
graph.plot.bar(y = 'Frequency', color = 'Purple', ylabel = 'Frequency', legend = None, figsize = (10,6))
plt.show()

# %%
Logs.Location.value_counts(ascending = True).plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
Logs_export = Logs.copy()

Logs_export.replace('','null',inplace=True)

Logs_export.to_csv('../Data/Logs_export.csv',index=False)
