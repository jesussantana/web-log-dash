# %% [markdown]
# # IT Academy - Data Science amb Python
# ## Tasca 7: Estructura de control
#
# ###  [Github Registre de Logs](https://github.com/jesussantana/Registre_de_logs)

# %% [markdown]
# ###  Exercici 1
# - Normalitza, identifica i enumera cada un dels atributs / variables de l'estructura de l'arxiu "Web_access_log-akumenius.com" que trobaràs al repositori de GitHub "Data-sources".

# %%
import numpy as np
import pandas as pd
from io import StringIO
import requests
import re

path = '../Data/Web_access_log-akumenius.com.txt'

Logs = pd.read_csv(path, sep='\s | - | \"', names =['DNS','IP','Location','Date','Time','Request','Status','Size','Referer','UserAgent'], skiprows = 261675, engine='python')

Logs
# Out:
#                                  DNS                              IP  \
# 0    www.akumenius.com 46.222.83.180  - [02/Mar/2014:02:24:44 +0100]
# 1    www.akumenius.com 46.222.83.180  - [02/Mar/2014:02:24:44 +0100]
# 2    www.akumenius.com 46.222.83.180  - [02/Mar/2014:02:24:44 +0100]
# 3    www.akumenius.com 46.222.83.180  - [02/Mar/2014:02:24:44 +0100]
# 4    www.akumenius.com 46.222.83.180  - [02/Mar/2014:02:24:44 +0100]
# ..                               ...                             ...
# 193   www.akumenius.com 5.255.253.53  - [02/Mar/2014:03:05:39 +0100]
# 194  www.akumenius.com 74.86.158.107  - [02/Mar/2014:03:09:52 +0100]
# 195              localhost 127.0.0.1  - [02/Mar/2014:03:10:18 +0100]
# 196              localhost 127.0.0.1  - [02/Mar/2014:03:10:18 +0100]
# 197              localhost 127.0.0.1  - [02/Mar/2014:03:10:18 +0100]
#
#                                               Location  \
# 0    GET /modules/raton/views/themes/bcoos/images/e...
# 1    GET /escapadas/cataluna-154_files/globe.jpg HT...
# 2    GET /modules/raton/views/themes/bcoos/images/e...
# 3    GET /modules/raton/views/themes/bcoos/images/e...
# 4    GET /modules/raton/views/themes/bcoos/images/e...
# ..                                                 ...
# 193                           GET / HTTP/1.1" 200 7528
# 194                               HEAD / HTTP/1.1" 200
# 195                            OPTIONS * HTTP/1.0" 200
# 196                            OPTIONS * HTTP/1.0" 200
# 197                            OPTIONS * HTTP/1.0" 200
#
#                                                   Date  \
# 0    http://www.akumenius.com/escapadas/romanticas-...
# 1    http://www.akumenius.com/escapadas/romanticas-...
# 2    http://www.akumenius.com/escapadas/romanticas-...
# 3    http://www.akumenius.com/escapadas/romanticas-...
# 4    http://www.akumenius.com/escapadas/romanticas-...
# ..                                                 ...
# 193                                                 -"
# 194                                                "-"
# 195                                                "-"
# 196                                                "-"
# 197                                                "-"
#
#                                                   Time  Request  Status  Size  \
# 0    Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...      NaN     NaN   NaN
# 1    Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...      NaN     NaN   NaN
# 2    Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...      NaN     NaN   NaN
# 3    Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...      NaN     NaN   NaN
# 4    Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...      NaN     NaN   NaN
# ..                                                 ...      ...     ...   ...
# 193  Mozilla/5.0 (compatible; YandexBot/3.0; +http:...      NaN     NaN   NaN
# 194  Mozilla/5.0+(compatible; UptimeRobot/2.0; http...      NaN     NaN   NaN
# 195         Apache (internal dummy connection)" VLOG=-      NaN     NaN   NaN
# 196         Apache (internal dummy connection)" VLOG=-      NaN     NaN   NaN
# 197         Apache (internal dummy connection)" VLOG=-      NaN     NaN   NaN
#
#      Referer  UserAgent
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN
# ..       ...        ...
# 193      NaN        NaN
# 194      NaN        NaN
# 195      NaN        NaN
# 196      NaN        NaN
# 197      NaN        NaN
#
# [198 rows x 10 columns]

# %% [markdown]
# ###  Exercici 2
# - Neteja, preprocesa, estructura i transforma (dataframe) les dades del registre d'Accés a la web.

# %%
Logs.shape
# Out:
# (198, 10)

# %%
Logs.isnull().sum()
# Out:
# DNS            0
# IP             0
# Location       0
# Date           0
# Time           0
# Request      198
# Status       198
# Size         198
# Referer      198
# UserAgent    198
# dtype: int64

# %%
Logs.UserAgent = Logs.Time
Logs.Request = Logs.Location
Logs.Referer = Logs.Date
Logs.Date = Logs.IP

Logs.head()
# Out:
#                                DNS                              IP  \
# 0  www.akumenius.com 46.222.83.180  - [02/Mar/2014:02:24:44 +0100]
# 1  www.akumenius.com 46.222.83.180  - [02/Mar/2014:02:24:44 +0100]
# 2  www.akumenius.com 46.222.83.180  - [02/Mar/2014:02:24:44 +0100]
# 3  www.akumenius.com 46.222.83.180  - [02/Mar/2014:02:24:44 +0100]
# 4  www.akumenius.com 46.222.83.180  - [02/Mar/2014:02:24:44 +0100]
#
#                                             Location  \
# 0  GET /modules/raton/views/themes/bcoos/images/e...
# 1  GET /escapadas/cataluna-154_files/globe.jpg HT...
# 2  GET /modules/raton/views/themes/bcoos/images/e...
# 3  GET /modules/raton/views/themes/bcoos/images/e...
# 4  GET /modules/raton/views/themes/bcoos/images/e...
#
#                              Date  \
# 0  - [02/Mar/2014:02:24:44 +0100]
# 1  - [02/Mar/2014:02:24:44 +0100]
# 2  - [02/Mar/2014:02:24:44 +0100]
# 3  - [02/Mar/2014:02:24:44 +0100]
# 4  - [02/Mar/2014:02:24:44 +0100]
#
#                                                 Time  \
# 0  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 1  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 2  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 3  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 4  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
#
#                                              Request  Status  Size  \
# 0  GET /modules/raton/views/themes/bcoos/images/e...     NaN   NaN
# 1  GET /escapadas/cataluna-154_files/globe.jpg HT...     NaN   NaN
# 2  GET /modules/raton/views/themes/bcoos/images/e...     NaN   NaN
# 3  GET /modules/raton/views/themes/bcoos/images/e...     NaN   NaN
# 4  GET /modules/raton/views/themes/bcoos/images/e...     NaN   NaN
#
#                                              Referer  \
# 0  http://www.akumenius.com/escapadas/romanticas-...
# 1  http://www.akumenius.com/escapadas/romanticas-...
# 2  http://www.akumenius.com/escapadas/romanticas-...
# 3  http://www.akumenius.com/escapadas/romanticas-...
# 4  http://www.akumenius.com/escapadas/romanticas-...
#
#                                            UserAgent
# 0  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 1  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 2  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 3  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 4  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...

# %%
Logs[['DNS','IP']] = Logs.DNS.str.split('\s', expand = True).get([0,1])

# %%
Logs.head()
# Out:
#                  DNS             IP  \
# 0  www.akumenius.com  46.222.83.180
# 1  www.akumenius.com  46.222.83.180
# 2  www.akumenius.com  46.222.83.180
# 3  www.akumenius.com  46.222.83.180
# 4  www.akumenius.com  46.222.83.180
#
#                                             Location  \
# 0  GET /modules/raton/views/themes/bcoos/images/e...
# 1  GET /escapadas/cataluna-154_files/globe.jpg HT...
# 2  GET /modules/raton/views/themes/bcoos/images/e...
# 3  GET /modules/raton/views/themes/bcoos/images/e...
# 4  GET /modules/raton/views/themes/bcoos/images/e...
#
#                              Date  \
# 0  - [02/Mar/2014:02:24:44 +0100]
# 1  - [02/Mar/2014:02:24:44 +0100]
# 2  - [02/Mar/2014:02:24:44 +0100]
# 3  - [02/Mar/2014:02:24:44 +0100]
# 4  - [02/Mar/2014:02:24:44 +0100]
#
#                                                 Time  \
# 0  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 1  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 2  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 3  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 4  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
#
#                                              Request  Status  Size  \
# 0  GET /modules/raton/views/themes/bcoos/images/e...     NaN   NaN
# 1  GET /escapadas/cataluna-154_files/globe.jpg HT...     NaN   NaN
# 2  GET /modules/raton/views/themes/bcoos/images/e...     NaN   NaN
# 3  GET /modules/raton/views/themes/bcoos/images/e...     NaN   NaN
# 4  GET /modules/raton/views/themes/bcoos/images/e...     NaN   NaN
#
#                                              Referer  \
# 0  http://www.akumenius.com/escapadas/romanticas-...
# 1  http://www.akumenius.com/escapadas/romanticas-...
# 2  http://www.akumenius.com/escapadas/romanticas-...
# 3  http://www.akumenius.com/escapadas/romanticas-...
# 4  http://www.akumenius.com/escapadas/romanticas-...
#
#                                            UserAgent
# 0  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 1  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 2  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 3  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 4  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...

# %%
Logs.DNS.unique()
# Out:
# array(['www.akumenius.com', 'localhost', 'akumenius.com', 'akumenius.es'],
#       dtype=object)

# %%
Logs.Time = Logs.Date.str.extract(':(\d{2}:\d{2}:\d{2}.*)]')

# %%
Logs.Date= Logs.Date.str.extract('(\d+/\w+/\d+)')

# %%
Logs
# Out:
#                    DNS             IP  \
# 0    www.akumenius.com  46.222.83.180
# 1    www.akumenius.com  46.222.83.180
# 2    www.akumenius.com  46.222.83.180
# 3    www.akumenius.com  46.222.83.180
# 4    www.akumenius.com  46.222.83.180
# ..                 ...            ...
# 193  www.akumenius.com   5.255.253.53
# 194  www.akumenius.com  74.86.158.107
# 195          localhost      127.0.0.1
# 196          localhost      127.0.0.1
# 197          localhost      127.0.0.1
#
#                                               Location         Date  \
# 0    GET /modules/raton/views/themes/bcoos/images/e...  02/Mar/2014
# 1    GET /escapadas/cataluna-154_files/globe.jpg HT...  02/Mar/2014
# 2    GET /modules/raton/views/themes/bcoos/images/e...  02/Mar/2014
# 3    GET /modules/raton/views/themes/bcoos/images/e...  02/Mar/2014
# 4    GET /modules/raton/views/themes/bcoos/images/e...  02/Mar/2014
# ..                                                 ...          ...
# 193                           GET / HTTP/1.1" 200 7528  02/Mar/2014
# 194                               HEAD / HTTP/1.1" 200  02/Mar/2014
# 195                            OPTIONS * HTTP/1.0" 200  02/Mar/2014
# 196                            OPTIONS * HTTP/1.0" 200  02/Mar/2014
# 197                            OPTIONS * HTTP/1.0" 200  02/Mar/2014
#
#                Time                                            Request  \
# 0    02:24:44 +0100  GET /modules/raton/views/themes/bcoos/images/e...
# 1    02:24:44 +0100  GET /escapadas/cataluna-154_files/globe.jpg HT...
# 2    02:24:44 +0100  GET /modules/raton/views/themes/bcoos/images/e...
# 3    02:24:44 +0100  GET /modules/raton/views/themes/bcoos/images/e...
# 4    02:24:44 +0100  GET /modules/raton/views/themes/bcoos/images/e...
# ..              ...                                                ...
# 193  03:05:39 +0100                           GET / HTTP/1.1" 200 7528
# 194  03:09:52 +0100                               HEAD / HTTP/1.1" 200
# 195  03:10:18 +0100                            OPTIONS * HTTP/1.0" 200
# 196  03:10:18 +0100                            OPTIONS * HTTP/1.0" 200
# 197  03:10:18 +0100                            OPTIONS * HTTP/1.0" 200
#
#      Status  Size                                            Referer  \
# 0       NaN   NaN  http://www.akumenius.com/escapadas/romanticas-...
# 1       NaN   NaN  http://www.akumenius.com/escapadas/romanticas-...
# 2       NaN   NaN  http://www.akumenius.com/escapadas/romanticas-...
# 3       NaN   NaN  http://www.akumenius.com/escapadas/romanticas-...
# 4       NaN   NaN  http://www.akumenius.com/escapadas/romanticas-...
# ..      ...   ...                                                ...
# 193     NaN   NaN                                                 -"
# 194     NaN   NaN                                                "-"
# 195     NaN   NaN                                                "-"
# 196     NaN   NaN                                                "-"
# 197     NaN   NaN                                                "-"
#
#                                              UserAgent
# 0    Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 1    Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 2    Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 3    Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 4    Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# ..                                                 ...
# 193  Mozilla/5.0 (compatible; YandexBot/3.0; +http:...
# 194  Mozilla/5.0+(compatible; UptimeRobot/2.0; http...
# 195         Apache (internal dummy connection)" VLOG=-
# 196         Apache (internal dummy connection)" VLOG=-
# 197         Apache (internal dummy connection)" VLOG=-
#
# [198 rows x 10 columns]

# %%
Logs[['Request','Status']] = Logs.Request.str.split('\"', expand = True).get([0,1])

# %%
Logs.head()
# Out:
#                  DNS             IP  \
# 0  www.akumenius.com  46.222.83.180
# 1  www.akumenius.com  46.222.83.180
# 2  www.akumenius.com  46.222.83.180
# 3  www.akumenius.com  46.222.83.180
# 4  www.akumenius.com  46.222.83.180
#
#                                             Location         Date  \
# 0  GET /modules/raton/views/themes/bcoos/images/e...  02/Mar/2014
# 1  GET /escapadas/cataluna-154_files/globe.jpg HT...  02/Mar/2014
# 2  GET /modules/raton/views/themes/bcoos/images/e...  02/Mar/2014
# 3  GET /modules/raton/views/themes/bcoos/images/e...  02/Mar/2014
# 4  GET /modules/raton/views/themes/bcoos/images/e...  02/Mar/2014
#
#              Time                                            Request  \
# 0  02:24:44 +0100  GET /modules/raton/views/themes/bcoos/images/e...
# 1  02:24:44 +0100  GET /escapadas/cataluna-154_files/globe.jpg HT...
# 2  02:24:44 +0100  GET /modules/raton/views/themes/bcoos/images/e...
# 3  02:24:44 +0100  GET /modules/raton/views/themes/bcoos/images/e...
# 4  02:24:44 +0100  GET /modules/raton/views/themes/bcoos/images/e...
#
#       Status  Size                                            Referer  \
# 0   200 2137   NaN  http://www.akumenius.com/escapadas/romanticas-...
# 1   200 3100   NaN  http://www.akumenius.com/escapadas/romanticas-...
# 2   200 3512   NaN  http://www.akumenius.com/escapadas/romanticas-...
# 3   200 5197   NaN  http://www.akumenius.com/escapadas/romanticas-...
# 4   200 3575   NaN  http://www.akumenius.com/escapadas/romanticas-...
#
#                                            UserAgent
# 0  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 1  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 2  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 3  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 4  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...

# %%
Logs.Size = Logs.Status.str.extract('(\d+$)')
Logs.head()
# Out:
#                  DNS             IP  \
# 0  www.akumenius.com  46.222.83.180
# 1  www.akumenius.com  46.222.83.180
# 2  www.akumenius.com  46.222.83.180
# 3  www.akumenius.com  46.222.83.180
# 4  www.akumenius.com  46.222.83.180
#
#                                             Location         Date  \
# 0  GET /modules/raton/views/themes/bcoos/images/e...  02/Mar/2014
# 1  GET /escapadas/cataluna-154_files/globe.jpg HT...  02/Mar/2014
# 2  GET /modules/raton/views/themes/bcoos/images/e...  02/Mar/2014
# 3  GET /modules/raton/views/themes/bcoos/images/e...  02/Mar/2014
# 4  GET /modules/raton/views/themes/bcoos/images/e...  02/Mar/2014
#
#              Time                                            Request  \
# 0  02:24:44 +0100  GET /modules/raton/views/themes/bcoos/images/e...
# 1  02:24:44 +0100  GET /escapadas/cataluna-154_files/globe.jpg HT...
# 2  02:24:44 +0100  GET /modules/raton/views/themes/bcoos/images/e...
# 3  02:24:44 +0100  GET /modules/raton/views/themes/bcoos/images/e...
# 4  02:24:44 +0100  GET /modules/raton/views/themes/bcoos/images/e...
#
#       Status  Size                                            Referer  \
# 0   200 2137  2137  http://www.akumenius.com/escapadas/romanticas-...
# 1   200 3100  3100  http://www.akumenius.com/escapadas/romanticas-...
# 2   200 3512  3512  http://www.akumenius.com/escapadas/romanticas-...
# 3   200 5197  5197  http://www.akumenius.com/escapadas/romanticas-...
# 4   200 3575  3575  http://www.akumenius.com/escapadas/romanticas-...
#
#                                            UserAgent
# 0  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 1  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 2  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 3  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 4  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...

# %%
Logs.Status = Logs.Status.str.extract('(\d{3})')
Logs.head()
# Out:
#                  DNS             IP  \
# 0  www.akumenius.com  46.222.83.180
# 1  www.akumenius.com  46.222.83.180
# 2  www.akumenius.com  46.222.83.180
# 3  www.akumenius.com  46.222.83.180
# 4  www.akumenius.com  46.222.83.180
#
#                                             Location         Date  \
# 0  GET /modules/raton/views/themes/bcoos/images/e...  02/Mar/2014
# 1  GET /escapadas/cataluna-154_files/globe.jpg HT...  02/Mar/2014
# 2  GET /modules/raton/views/themes/bcoos/images/e...  02/Mar/2014
# 3  GET /modules/raton/views/themes/bcoos/images/e...  02/Mar/2014
# 4  GET /modules/raton/views/themes/bcoos/images/e...  02/Mar/2014
#
#              Time                                            Request Status  \
# 0  02:24:44 +0100  GET /modules/raton/views/themes/bcoos/images/e...    200
# 1  02:24:44 +0100  GET /escapadas/cataluna-154_files/globe.jpg HT...    200
# 2  02:24:44 +0100  GET /modules/raton/views/themes/bcoos/images/e...    200
# 3  02:24:44 +0100  GET /modules/raton/views/themes/bcoos/images/e...    200
# 4  02:24:44 +0100  GET /modules/raton/views/themes/bcoos/images/e...    200
#
#    Size                                            Referer  \
# 0  2137  http://www.akumenius.com/escapadas/romanticas-...
# 1  3100  http://www.akumenius.com/escapadas/romanticas-...
# 2  3512  http://www.akumenius.com/escapadas/romanticas-...
# 3  5197  http://www.akumenius.com/escapadas/romanticas-...
# 4  3575  http://www.akumenius.com/escapadas/romanticas-...
#
#                                            UserAgent
# 0  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 1  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 2  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 3  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 4  Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...

# %% [markdown]
# ###  Exercici 3
# - Geolocalitza les IP's. Aqui tens una pagina de interes:
#   - [IP2Locattion](https://blog.ip2location.com/knowledge-base/how-to-add-a-sub-account-in-ip2location/)

# %%
import json
from ip2geotools.databases.noncommercial import DbIpCity

# %%
localhost = "127.0.0.1"

def location(ip):
    
    try:
        if ip == localhost:
            return "Local"
        else:
            response = DbIpCity.get(ip, api_key = 'free').to_json()    
            data = json.loads(response)
            return data['city'], data['country']
    
    except:
        return np.nan

# %%
location(Logs.IP[1])
# Out:
# ('Barcelona', 'ES')

# %%
for index, row in Logs.iterrows(): 
        
   row.Location = location(row.IP)

# %%
Logs
# Out:
#                    DNS             IP  \
# 0    www.akumenius.com  46.222.83.180
# 1    www.akumenius.com  46.222.83.180
# 2    www.akumenius.com  46.222.83.180
# 3    www.akumenius.com  46.222.83.180
# 4    www.akumenius.com  46.222.83.180
# ..                 ...            ...
# 193  www.akumenius.com   5.255.253.53
# 194  www.akumenius.com  74.86.158.107
# 195          localhost      127.0.0.1
# 196          localhost      127.0.0.1
# 197          localhost      127.0.0.1
#
#                                               Location         Date  \
# 0                                      (Barcelona, ES)  02/Mar/2014
# 1                                      (Barcelona, ES)  02/Mar/2014
# 2                                      (Barcelona, ES)  02/Mar/2014
# 3                                      (Barcelona, ES)  02/Mar/2014
# 4                                      (Barcelona, ES)  02/Mar/2014
# ..                                                 ...          ...
# 193  (Moscow (Tsentralnyy administrativnyy okrug), RU)  02/Mar/2014
# 194                                      (Chicago, US)  02/Mar/2014
# 195                                              Local  02/Mar/2014
# 196                                              Local  02/Mar/2014
# 197                                              Local  02/Mar/2014
#
#                Time                                            Request Status  \
# 0    02:24:44 +0100  GET /modules/raton/views/themes/bcoos/images/e...    200
# 1    02:24:44 +0100  GET /escapadas/cataluna-154_files/globe.jpg HT...    200
# 2    02:24:44 +0100  GET /modules/raton/views/themes/bcoos/images/e...    200
# 3    02:24:44 +0100  GET /modules/raton/views/themes/bcoos/images/e...    200
# 4    02:24:44 +0100  GET /modules/raton/views/themes/bcoos/images/e...    200
# ..              ...                                                ...    ...
# 193  03:05:39 +0100                                     GET / HTTP/1.1    200
# 194  03:09:52 +0100                                    HEAD / HTTP/1.1    200
# 195  03:10:18 +0100                                 OPTIONS * HTTP/1.0    200
# 196  03:10:18 +0100                                 OPTIONS * HTTP/1.0    200
# 197  03:10:18 +0100                                 OPTIONS * HTTP/1.0    200
#
#      Size                                            Referer  \
# 0    2137  http://www.akumenius.com/escapadas/romanticas-...
# 1    3100  http://www.akumenius.com/escapadas/romanticas-...
# 2    3512  http://www.akumenius.com/escapadas/romanticas-...
# 3    5197  http://www.akumenius.com/escapadas/romanticas-...
# 4    3575  http://www.akumenius.com/escapadas/romanticas-...
# ..    ...                                                ...
# 193  7528                                                 -"
# 194   200                                                "-"
# 195   200                                                "-"
# 196   200                                                "-"
# 197   200                                                "-"
#
#                                              UserAgent
# 0    Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 1    Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 2    Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 3    Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# 4    Mozilla/5.0 (Linux; Android 4.3; GT-I9300 Buil...
# ..                                                 ...
# 193  Mozilla/5.0 (compatible; YandexBot/3.0; +http:...
# 194  Mozilla/5.0+(compatible; UptimeRobot/2.0; http...
# 195         Apache (internal dummy connection)" VLOG=-
# 196         Apache (internal dummy connection)" VLOG=-
# 197         Apache (internal dummy connection)" VLOG=-
#
# [198 rows x 10 columns]

# %% [markdown]
# ###  Exercici 4
# - Mostreu-me la teva creativitat, Sorprèn-me fes un pas més enllà amb el analysis anterior.
